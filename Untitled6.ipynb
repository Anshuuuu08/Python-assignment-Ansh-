# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshuuuu08/Python-assignment-Ansh-/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating a tuple
t = (5, 2, 9, 1, 7)

# Using built-in functions
print("Length:", len(t))
print("Maximum value:", max(t))
print("Minimum value:", min(t))

# Using tuple() function
lst = [1, 2, 3]
t2 = tuple(lst)
print("Converted tuple:", t2) # Creating a tuple
t = (1, 2, 3)

assignment 7
# Trying to modify (will give error if uncommented)
# t[0] = 10

print("Tuples are immutable (cannot be changed)")

# Deleting tuple
del t
print("Tuple deleted successfully") # Creating a tuple
t = (10, 20, 30, 40, 50)

# Indexing
print("Element at index 0:", t[0])

# Negative Indexing
print("Element at last index:", t[-1])

# Slicing
print("Elements from index 1 to 3:", t[1:4])

# Iteration
print("Iterating elements:")
for i in t:
    print(i) # Creating a tuple
    t1 = (1, 2, 3, 4)

    # Finding length
    print("Length of tuple:", len(t1))

    # Concatenation
    t2 = (5, 6)
    t3 = t1 + t2
    print("After concatenation:", t3)

    # Repetition
    print("After repetition:", t1 * 2)

    # Membership
    print("Is 3 present in tuple?", 3 in t1)
# Out:
# Length: 5
# Maximum value: 9
# Minimum value: 1
# Converted tuple: (1, 2, 3)
# Tuples are immutable (cannot be changed)
# Tuple deleted successfully
# Element at index 0: 10
# Element at last index: 50
# Elements from index 1 to 3: (20, 30, 40)
# Iterating elements:
# 10
# Length of tuple: 4
# After concatenation: (1, 2, 3, 4, 5, 6)
# After repetition: (1, 2, 3, 4, 1, 2, 3, 4)
# Is 3 present in tuple? True
# 20
# Length of tuple: 4
# After concatenation: (1, 2, 3, 4, 5, 6)
# After repetition: (1, 2, 3, 4, 1, 2, 3, 4)
# Is 3 present in tuple? True
# 30
# Length of tuple: 4
# After concatenation: (1, 2, 3, 4, 5, 6)
# After repetition: (1, 2, 3, 4, 1, 2, 3, 4)
# Is 3 present in tuple? True
# 40
# Length of tuple: 4
# After concatenation: (1, 2, 3, 4, 5, 6)
# After repetition: (1, 2, 3, 4, 1, 2, 3, 4)
# Is 3 present in tuple? True
# 50
# Length of tuple: 4
# After concatenation: (1, 2, 3, 4, 5, 6)
# After repetition: (1, 2, 3, 4, 1, 2, 3, 4)
# Is 3 present in tuple? True
